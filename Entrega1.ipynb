# %% [markdown]
# <a href="https://colab.research.google.com/github/vmunozu3/vmunozu3/blob/main/Entrega1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#----------Mensaje de bienvenidaa------------
print("¡Bienvenido al buscaminas!💣")
print()

#-----Solicitud de nombre y validación de nombre------

while True:
    nombre=input("🔵Ingrese su nombre: ")

    if nombre.isalpha() and nombre != "":
        break
    else:
        print("❌ No es válido, debe ingresar letras y que no esté vacío")

print()

#------solicitud de filas y columnas y validación-------

while True:
    filas=int(input("🔵Ingrese el número de filas: "))

    if filas>0:
        break
    else:
        print("❌ No es válido.")

print()


while True:
    columnas=int(input("🔵Ingrese el número de columnas: "))

    if columnas>0:
        break
    else:
        print("❌ No es válido.")

print()

#-------solicitud de número de minas y validación---------
while True:
    minas=int(input("🔵Ingrese el número de minas: "))

    if 0<minas<=filas*columnas:
        break
    else:
        print("❌ Ingrese un valor válido")

print()

#-----------Tablero básico 3x3-----------

print("🟦🟦1️⃣2️⃣3️⃣🟦🟦")
print("🟦➕➖➖➖➕🟦")
print("1️⃣➕▫️▫️▫️➕🟦")
print("2️⃣➕▫️▫️▫️➕🟦")
print("3️⃣➕▫️▫️▫️➕🟦")
print("🟦➕➖➖➖➕🟦")
print("🟦🟦🟦🟦🟦🟦🟦")

print()

#------Ahora, para marcar una casilla en el tablero-----

print("¿Quieres marcar una casilla en el tablero?👌")
print()

tablero = [
    ["▫️", "▫️", "▫️"],
    ["▫️", "▫️", "▫️"],
    ["▫️", "▫️", "▫️"]
]

#------Validaciones para que no haya posiciones fuera del tablero, marcar casilla y tablero final------

while True:

  fila_marcada=int(input("🔷Ingrese el número de fila: "))

  columna_marcada=int(input("🔷Ingrese el número de columna: "))
  print()

  if fila_marcada < 1 or fila_marcada > 3 or columna_marcada < 1 or columna_marcada > 3:
      print("❌ Posición no está en el tablero")
      print()
  else:
      tablero[fila_marcada-1][columna_marcada-1] = "❌"

      print("Tablero con la casilla marcada:\n")
      print("🟦🟦1️⃣2️⃣3️⃣🟦🟦")
      print("🟦➕➖➖➖➕🟦")
      print("1️⃣➕" + "".join(tablero[0]) + "➕🟦")
      print("2️⃣➕" + "".join(tablero[1]) + "➕🟦")
      print("3️⃣➕" + "".join(tablero[2]) + "➕🟦")
      print("🟦➕➖➖➖➕🟦")
      print("🟦🟦🟦🟦🟦🟦🟦")

      break

#Listoooo:3


#------------------------------------------Conocimiento nuevo :o -----------------------------------------

#Lista de listas: lista donde cada elemento es una lista, la usé para representar el tablero como una matriz
#y poder marcar las casillas como si fueran coordenadas.

#tablero[fila_marcada-1] = selecciona una de las filas, que es un elemento, [columna_marcada-1] selecciona
#el elemento específico dentro de la lista. Se usa un -1 porque para python los índices empiezan en cero,
#entonces para decirle a python que seleccione por ejemplo la fila 1 y columna 1, se le dice que seleccione
#la fila 0 y columna 0

#.join(tablero[n]): tablero[n] es la fila n. "".join() sirve para unir todos los elementos de la lista en una
#sola string, en las comillas se pone lo que separa los elementos, en este caso, está vacío.

#Poner el input dentro del while para que se repita la pregunta
# Out:
# ¡Bienvenido al buscaminas!💣
#
# 🔵Ingrese su nombre: val
#
# 🔵Ingrese el número de filas: 2
#
# 🔵Ingrese el número de columnas: 2
#
# 🔵Ingrese el número de minas: 2
#
# 🟦🟦1️⃣2️⃣3️⃣🟦🟦
# 🟦➕➖➖➖➕🟦
# 1️⃣➕▫️▫️▫️➕🟦
# 2️⃣➕▫️▫️▫️➕🟦
# 3️⃣➕▫️▫️▫️➕🟦
# 🟦➕➖➖➖➕🟦
# 🟦🟦🟦🟦🟦🟦🟦
#
# ¿Quieres marcar una casilla en el tablero?👌
#
# 🔷Ingrese el número de fila: 5
# 🔷Ingrese el número de columna: 5
#
# ❌ Posición no está en el tablero
#
# 🔷Ingrese el número de fila: 1
# 🔷Ingrese el número de columna: 2
#
# Tablero con la casilla marcada:
#
# 🟦🟦1️⃣2️⃣3️⃣🟦🟦
# 🟦➕➖➖➖➕🟦
# 1️⃣➕▫️❌▫️➕🟦
# 2️⃣➕▫️▫️▫️➕🟦
# 3️⃣➕▫️▫️▫️➕🟦
# 🟦➕➖➖➖➕🟦
# 🟦🟦🟦🟦🟦🟦🟦
